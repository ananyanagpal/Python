# %%
import pandas as pd

# %%
food=pd.read_csv (r"C:\Users\anany\Downloads\foods.csv")

# %%
food
# Out:
#     First Name  Gender          City Frequency       Item  Spend
# 0        Wanda  Female      Stamford    Weekly     Burger  15.66
# 1         Eric    Male      Stamford     Daily    Chalupa  10.56
# 2      Charles    Male      New York     Never      Sushi  42.14
# 3         Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4      Deborah  Female  Philadelphia     Daily    Chalupa  23.49
# ..         ...     ...           ...       ...        ...    ...
# 995      Donna  Female      New York   Monthly      Sushi  83.53
# 996     Albert    Male  Philadelphia     Daily      Sushi  72.88
# 997       Jean  Female      Stamford    Weekly      Donut   5.85
# 998    Jessica  Female      New York     Daily    Chalupa  43.19
# 999      Brian    Male      New York     Daily    Chalupa  28.36
#
# [1000 rows x 6 columns]

# %%
week2=pd.read_csv (r"C:\Users\anany\Downloads\restaurant_week_2_sales.csv")

# %%
week2
# Out:
#      Customer ID  Food ID
# 0            688       10
# 1            813        7
# 2            495       10
# 3            189        5
# 4            267        3
# ..           ...      ...
# 245          783       10
# 246          556       10
# 247          547        9
# 248          252        9
# 249          249        6
#
# [250 rows x 2 columns]

# %%
week1sales= pd.read_csv(r"C:\Users\anany\Downloads\restaurant_week_1_sales.csv")

# %%
week1sales
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          413        9
# 246          926        6
# 247          134        3
# 248          396        6
# 249          535       10
#
# [250 rows x 2 columns]

# %%
week1=pd.read_csv(r"C:\Users\anany\Downloads\restaurant_week_1_times.csv")

# %%
week1
# Out:
#     Time of Day
# 0      14:54:59
# 1      20:55:17
# 2      01:16:22
# 3      16:17:26
# 4      19:26:11
# ..          ...
# 245    04:44:14
# 246    07:46:21
# 247    20:45:08
# 248    01:09:06
# 249    18:18:50
#
# [250 rows x 1 columns]

# %%
customer=pd.read_csv (r"C:\Users\anany\Downloads\restaurant_customers.csv")

# %%
customer
# Out:
#        ID First Name Last Name  Gender       Company  \
# 0       1     Joseph   Perkins    Male       Dynazzy
# 1       2   Jennifer   Alvarez  Female          DabZ
# 2       3      Roger     Black    Male       Tagfeed
# 3       4     Steven     Evans    Male          Fatz
# 4       5       Judy  Morrison  Female       Demivee
# ..    ...        ...       ...     ...           ...
# 995   996      Debra    Garcia  Female  Dazzlesphere
# 996   997    Douglas    Bishop    Male      Livepath
# 997   998      Frank  Franklin    Male    Brainverse
# 998   999    Jessica     Burns  Female    Babbleblab
# 999  1000      Brian   Daniels    Male         Tazzy
#
#                         Occupation
# 0    Community Outreach Specialist
# 1          Senior Quality Engineer
# 2                Account Executive
# 3                 Registered Nurse
# 4                  Legal Assistant
# ..                             ...
# 995            Structural Engineer
# 996                    Developer I
# ...

# %%
week2.merge(customer,how="left",left_on="Customer ID", right_on="ID")
# Out:
#      Customer ID  Food ID   ID First Name   Last Name  Gender       Company  \
# 0            688       10  688       Carl  Williamson    Male    Thoughtmix
# 1            813        7  813     Johnny      Walker    Male        Kayveo
# 2            495       10  495    Deborah      Little  Female    Babbleblab
# 3            189        5  189      Roger      Gordon    Male       Skilith
# 4            267        3  267    Matthew        Wood    Male        Agimba
# ..           ...      ...  ...        ...         ...     ...           ...
# 245          783       10  783    Phyllis       Meyer  Female        Voolia
# 246          556       10  556     Samuel      Bailey    Male        Oyoloo
# 247          547        9  547       Tina     Watkins  Female  Thoughtstorm
# 248          252        9  252    Douglas      Powell    Male       Jetwire
# 249          249        6  249    Anthony   Carpenter    Male    Shuffletag
#
#                       Occupation
# ...

# %%
week2.merge(customer,how="left",left_on="Customer ID", right_on="ID").drop("ID",axis="columns")
# Out:
#      Customer ID  Food ID First Name   Last Name  Gender       Company  \
# 0            688       10       Carl  Williamson    Male    Thoughtmix
# 1            813        7     Johnny      Walker    Male        Kayveo
# 2            495       10    Deborah      Little  Female    Babbleblab
# 3            189        5      Roger      Gordon    Male       Skilith
# 4            267        3    Matthew        Wood    Male        Agimba
# ..           ...      ...        ...         ...     ...           ...
# 245          783       10    Phyllis       Meyer  Female        Voolia
# 246          556       10     Samuel      Bailey    Male        Oyoloo
# 247          547        9       Tina     Watkins  Female  Thoughtstorm
# 248          252        9    Douglas      Powell    Male       Jetwire
# 249          249        6    Anthony   Carpenter    Male    Shuffletag
#
#                       Occupation
# 0               Graphic Designer
# 1                   Developer II
# ...

# %%
week1sales.merge(week2,how="inner",on="Customer ID",suffixes=["-week1","week2"])
# Out:
#     Customer ID  Food ID-week1  Food IDweek2
# 0           537              9             5
# 1           155              9             3
# 2           503              5             8
# 3           503              5             9
# 4           155              1             3
# ..          ...            ...           ...
# 57          945              5             4
# 58          343              3             5
# 59          343              3             2
# 60          343              3             7
# 61          621              9             6
#
# [62 rows x 3 columns]

# %%
week1sales[week1sales["Customer ID"] == 155]
# Out:
#     Customer ID  Food ID
# 4           155        9
# 17          155        1

# %%
week2[week2["Customer ID"] == 155]
# Out:
#      Customer ID  Food ID
# 208          155        3

# %%
week1sales.head()
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1
# 3          202        2
# 4          155        9

# %%
week2.head()
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10
# 3          189        5
# 4          267        3

# %%
week1sales.merge(week2,how="inner",on=["Customer ID","Food ID"])
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5          922        1
# 6           21        4
# 7          578        5
# 8          578        5

# %%
condition_one=week1sales["Customer ID"] == 578
condition_two=week1sales["Food ID"] == 5
week1sales[condition_one&condition_two]
# Out:
#      Customer ID  Food ID
# 224          578        5

# %%
condition_one=week2["Customer ID"] == 578
condition_two=week2["Food ID"] == 5
week2[condition_one&condition_two]
# Out:
#      Customer ID  Food ID
# 29           578        5
# 189          578        5

# %%
#Outer Joins

# %%
week1sales.merge(week2,how="outer",on="Customer ID")
# Out:
#      Customer ID  Food ID_x  Food ID_y
# 0              3        2.0        NaN
# 1              8        NaN        6.0
# 2             10        2.0        NaN
# 3             13        NaN        2.0
# 4             20        1.0        NaN
# ..           ...        ...        ...
# 449          985        5.0        NaN
# 450          991        2.0        NaN
# 451          994        NaN        2.0
# 452          996        NaN       10.0
# 453         1000        2.0        NaN
#
# [454 rows x 3 columns]

# %%
week1sales.merge(week2,how="outer",on="Customer ID",suffixes=["-week1","-week2"])
# Out:
#      Customer ID  Food ID-week1  Food ID-week2
# 0              3            2.0            NaN
# 1              8            NaN            6.0
# 2             10            2.0            NaN
# 3             13            NaN            2.0
# 4             20            1.0            NaN
# ..           ...            ...            ...
# 449          985            5.0            NaN
# 450          991            2.0            NaN
# 451          994            NaN            2.0
# 452          996            NaN           10.0
# 453         1000            2.0            NaN
#
# [454 rows x 3 columns]

# %%
week1sales.merge(week2,how="outer",on="Customer ID",suffixes=["-week1","-week2"],indicator=True)
# Out:
#      Customer ID  Food ID-week1  Food ID-week2      _merge
# 0              3            2.0            NaN   left_only
# 1              8            NaN            6.0  right_only
# 2             10            2.0            NaN   left_only
# 3             13            NaN            2.0  right_only
# 4             20            1.0            NaN   left_only
# ..           ...            ...            ...         ...
# 449          985            5.0            NaN   left_only
# 450          991            2.0            NaN   left_only
# 451          994            NaN            2.0  right_only
# 452          996            NaN           10.0  right_only
# 453         1000            2.0            NaN   left_only
#
# [454 rows x 4 columns]

# %%
week2.merge(week1sales,how="outer",on="Customer ID",suffixes=["-week1","-week2"])
# Out:
#      Customer ID  Food ID-week1  Food ID-week2
# 0              3            NaN            2.0
# 1              8            6.0            NaN
# 2             10            NaN            2.0
# 3             13            2.0            NaN
# 4             20            NaN            1.0
# ..           ...            ...            ...
# 449          985            NaN            5.0
# 450          991            NaN            2.0
# 451          994            2.0            NaN
# 452          996           10.0            NaN
# 453         1000            NaN            2.0
#
# [454 rows x 3 columns]

# %%
week2.merge(week1sales,how="outer",on="Customer ID",suffixes=["-week1","-week2"],indicator=True)
# Out:
#      Customer ID  Food ID-week1  Food ID-week2      _merge
# 0              3            NaN            2.0  right_only
# 1              8            6.0            NaN   left_only
# 2             10            NaN            2.0  right_only
# 3             13            2.0            NaN   left_only
# 4             20            NaN            1.0  right_only
# ..           ...            ...            ...         ...
# 449          985            NaN            5.0  right_only
# 450          991            NaN            2.0  right_only
# 451          994            2.0            NaN   left_only
# 452          996           10.0            NaN   left_only
# 453         1000            NaN            2.0  right_only
#
# [454 rows x 4 columns]

# %%
merged=week1sales.merge(week2,how="outer",on="Customer ID",suffixes=["-week1","-week2"],indicator="True")
merged["_merge"].value_counts()
merged[merged["_merge"].isin(["left_only","right_only"])]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\AnanyaAnaconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '_merge'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 2
# ...

# %%
food=pd.read_csv (r"C:\Users\anany\Downloads\foods.csv",index_col="Food ID")
week2=pd.read_csv (r"C:\Users\anany\Downloads\restaurant_week_2_sales.csv")
week1sales= pd.read_csv(r"C:\Users\anany\Downloads\restaurant_week_1_sales.csv")
customer=pd.read_csv (r"C:\Users\anany\Downloads\restaurant_customers.csv",index_col="ID")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 food=pd.read_csv (r"C:\Users\anany\Downloads\foods.csv",index_col="Food ID")
#       2 week2=pd.read_csv (r"C:\Users\anany\Downloads\restaurant_week_2_sales.csv")
#       3 week1sales= pd.read_csv(r"C:\Users\anany\Downloads\restaurant_week_1_sales.csv")
#
# ...
